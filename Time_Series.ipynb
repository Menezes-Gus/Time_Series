# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw = pd.read_csv('inputs/Index2018.csv')
df = raw.copy()

# %%
df.head()
# Out:
#          date     spx      dax     ftse    nikkei
# 0  07/01/1994  469.90  2224.95  3445.98  18124.01
# 1  10/01/1994  475.27  2225.00  3440.58  18443.44
# 2  11/01/1994  474.13  2228.10  3413.77  18485.25
# 3  12/01/1994  474.17  2182.06  3372.02  18793.88
# 4  13/01/1994  472.47  2142.37  3360.01  18577.26

# %%
df.describe()
# Out:
#                spx           dax         ftse        nikkei
# count  6269.000000   6269.000000  6269.000000   6269.000000
# mean   1288.127542   6080.063363  5422.713545  14597.055700
# std     487.586473   2754.361032  1145.572428   4043.122953
# min     438.920000   1911.700000  2876.600000   7054.980000
# 25%     990.671905   4069.350000  4486.100000  10709.290000
# 50%    1233.420000   5773.340000  5662.430000  15028.170000
# 75%    1459.987747   7443.070000  6304.250000  17860.470000
# max    2872.867839  13559.600000  7778.637689  24124.150000

# %%
df.isna().sum()
# Out:
# date      0
# spx       0
# dax       0
# ftse      0
# nikkei    0
# dtype: int64

# %%
df['spx'].plot(title='S&P 500 Prices', figsize=(18,5))
# Out:
# <AxesSubplot:title={'center':'S&P 500 Prices'}>

# %%
df['ftse'].plot(title='FTSE 100 Prices', figsize=(18,5))
# Out:
# <AxesSubplot:title={'center':'FTSE 100 Prices'}>

# %%
df['spx'].plot( figsize=(18,5))
df['ftse'].plot( figsize=(18,5))
plt.title("S&P vs FTSE")
plt.show()

# %%
import scipy.stats as st
import pylab

# %%
st.probplot(df['spx'],plot=pylab)
pylab.show()

# %%
df.date.describe()
# Out:
# count           6269
# unique          6269
# top       07/01/1994
# freq               1
# Name: date, dtype: object

# %%
df['date'] = pd.to_datetime(df['date'], dayfirst=True)
df
# Out:
#            date          spx       dax         ftse    nikkei
# 0    1994-01-07   469.900000   2224.95  3445.980000  18124.01
# 1    1994-01-10   475.270000   2225.00  3440.580000  18443.44
# 2    1994-01-11   474.130000   2228.10  3413.770000  18485.25
# 3    1994-01-12   474.170000   2182.06  3372.020000  18793.88
# 4    1994-01-13   472.470000   2142.37  3360.010000  18577.26
# ...         ...          ...       ...          ...       ...
# 6264 2018-01-23  2839.130362  13559.60  7731.827774  24124.15
# 6265 2018-01-24  2837.544008  13414.74  7643.428966  23940.78
# 6266 2018-01-25  2839.253031  13298.36  7615.839954  23669.49
# 6267 2018-01-26  2872.867839  13340.17  7665.541292  23631.88
# 6268 2018-01-29  2853.528411  13324.48  7671.533300  23629.34
#
# [6269 rows x 5 columns]

# %%
df['date'].describe()
# Out:
# C:\Users\menez\AppData\Local\Temp/ipykernel_10244/801468514.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df['date'].describe()
# count                    6269
# unique                   6269
# top       1994-01-07 00:00:00
# freq                        1
# first     1994-01-07 00:00:00
# last      2018-01-29 00:00:00
# Name: date, dtype: object

# %%
df.set_index('date', inplace=True)

# %%
df
# Out:
#                     spx       dax         ftse    nikkei
# date
# 1994-01-07   469.900000   2224.95  3445.980000  18124.01
# 1994-01-10   475.270000   2225.00  3440.580000  18443.44
# 1994-01-11   474.130000   2228.10  3413.770000  18485.25
# 1994-01-12   474.170000   2182.06  3372.020000  18793.88
# 1994-01-13   472.470000   2142.37  3360.010000  18577.26
# ...                 ...       ...          ...       ...
# 2018-01-23  2839.130362  13559.60  7731.827774  24124.15
# 2018-01-24  2837.544008  13414.74  7643.428966  23940.78
# 2018-01-25  2839.253031  13298.36  7615.839954  23669.49
# 2018-01-26  2872.867839  13340.17  7665.541292  23631.88
# 2018-01-29  2853.528411  13324.48  7671.533300  23629.34
#
# [6269 rows x 4 columns]

# %%
df = df.asfreq('b')
df
# Out:
#                     spx       dax         ftse    nikkei
# date
# 1994-01-07   469.900000   2224.95  3445.980000  18124.01
# 1994-01-10   475.270000   2225.00  3440.580000  18443.44
# 1994-01-11   474.130000   2228.10  3413.770000  18485.25
# 1994-01-12   474.170000   2182.06  3372.020000  18793.88
# 1994-01-13   472.470000   2142.37  3360.010000  18577.26
# ...                 ...       ...          ...       ...
# 2018-01-23  2839.130362  13559.60  7731.827774  24124.15
# 2018-01-24  2837.544008  13414.74  7643.428966  23940.78
# 2018-01-25  2839.253031  13298.36  7615.839954  23669.49
# 2018-01-26  2872.867839  13340.17  7665.541292  23631.88
# 2018-01-29  2853.528411  13324.48  7671.533300  23629.34
#
# [6277 rows x 4 columns]

# %%
df.isna().sum()
# Out:
# spx       8
# dax       8
# ftse      8
# nikkei    8
# dtype: int64

# %%
df['spx'] = df['spx'].fillna(method='ffill')
df.isna().sum()
# Out:
# spx       0
# dax       8
# ftse      8
# nikkei    8
# dtype: int64

# %%
df['ftse'] = df['ftse'].fillna(method='bfill')
df.isna().sum()
# Out:
# spx       0
# dax       8
# ftse      0
# nikkei    8
# dtype: int64

# %%
df['dax'] = df['dax'].fillna(value=df['dax'].mean())
df.isna().sum()
# Out:
# spx       0
# dax       0
# ftse      0
# nikkei    8
# dtype: int64

# %%
df['nikkei'] = df['nikkei'].fillna(method='ffill')
df.isna().sum()
# Out:
# spx       0
# dax       0
# ftse      0
# nikkei    0
# dtype: int64

# %%
df['market_value'] = df['spx']

# %%
del df['spx'], df['ftse'], df['dax'], df['nikkei']

# %%
df
# Out:
#             market_value
# date
# 1994-01-07    469.900000
# 1994-01-10    475.270000
# 1994-01-11    474.130000
# 1994-01-12    474.170000
# 1994-01-13    472.470000
# ...                  ...
# 2018-01-23   2839.130362
# 2018-01-24   2837.544008
# 2018-01-25   2839.253031
# 2018-01-26   2872.867839
# 2018-01-29   2853.528411
#
# [6277 rows x 1 columns]

# %%
size = int(len(df)*.8)

# %%
size
# Out:
# 5021

# %%
df_train = df.iloc[:size]
df_test = df.iloc[size:]

# %%
df_train
# Out:
#             market_value
# date
# 1994-01-07    469.900000
# 1994-01-10    475.270000
# 1994-01-11    474.130000
# 1994-01-12    474.170000
# 1994-01-13    472.470000
# ...                  ...
# 2013-04-01   1562.173837
# 2013-04-02   1570.252238
# 2013-04-03   1553.686978
# 2013-04-04   1559.979316
# 2013-04-05   1553.278930
#
# [5021 rows x 1 columns]

# %%
df_test
# Out:
#             market_value
# date
# 2013-04-08   1563.071269
# 2013-04-09   1568.607909
# 2013-04-10   1587.731827
# 2013-04-11   1593.369863
# 2013-04-12   1588.854623
# ...                  ...
# 2018-01-23   2839.130362
# 2018-01-24   2837.544008
# 2018-01-25   2839.253031
# 2018-01-26   2872.867839
# 2018-01-29   2853.528411
#
# [1256 rows x 1 columns]

# %%
wn = np.random.normal(loc=df_train['market_value'].mean(), scale=df_train['market_value'].std(), size=df_train.shape[0])
wn
# Out:
# array([1214.56375343,  765.15172865,  904.96532347, ..., 1206.4712037 ,
#        1066.550753  , 1220.25364206])

# %%
len(wn)
# Out:
# 5021

# %%
df_train['wn'] = wn
# Out:
# C:\Users\menez\AppData\Local\Temp/ipykernel_10244/2767877954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['wn'] = wn

# %%
df_train.isna().sum()
# Out:
# market_value    0
# wn              0
# dtype: int64

# %%
df_train
# Out:
#             market_value           wn
# date
# 1994-01-07    469.900000  1214.563753
# 1994-01-10    475.270000   765.151729
# 1994-01-11    474.130000   904.965323
# 1994-01-12    474.170000  1365.483868
# 1994-01-13    472.470000  1255.957173
# ...                  ...          ...
# 2013-04-01   1562.173837   748.920980
# 2013-04-02   1570.252238  1284.100890
# 2013-04-03   1553.686978  1206.471204
# 2013-04-04   1559.979316  1066.550753
# 2013-04-05   1553.278930  1220.253642
#
# [5021 rows x 2 columns]

# %%
df_train['wn'].plot(figsize=(20, 5))
plt.title('White Noise Time-Series', size=18)
plt.show()

# %%
df_train['market_value'].plot(figsize=(20, 5))
plt.title('S&P 500 Prices', size=18)
plt.ylim(0, 2300)
plt.show()

# %% [markdown]
# ## Section 2 - Random Walks

# %%
rw = pd.read_csv('inputs/RandWalk.csv')
rw['date'] = pd.to_datetime(rw['date'], dayfirst=True)

# %%
rw.set_index('date', inplace=True)
rw = rw.asfreq('b')
rw
# Out:
#                   price
# date
# 1994-01-07  1122.139662
# 1994-01-10  1080.347860
# 1994-01-11  1082.095245
# 1994-01-12  1083.639265
# 1994-01-13  1067.146255
# ...                 ...
# 2013-04-01  2263.675474
# 2013-04-02  2225.000870
# 2013-04-03  2190.787688
# 2013-04-04  2195.240033
# 2013-04-05  2152.992143
#
# [5021 rows x 1 columns]

# %%
df_train['rw'] = rw['price']
# Out:
# C:\Users\menez\AppData\Local\Temp/ipykernel_10244/2054090691.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['rw'] = rw['price']

# %%
df_train.head()
# Out:
#             market_value           wn           rw
# date
# 1994-01-07        469.90  1214.563753  1122.139662
# 1994-01-10        475.27   765.151729  1080.347860
# 1994-01-11        474.13   904.965323  1082.095245
# 1994-01-12        474.17  1365.483868  1083.639265
# 1994-01-13        472.47  1255.957173  1067.146255

# %%
df_train['rw'].plot(figsize=(18,5))
plt.title('Random Walk')
plt.show()

# %%
df_train['rw'].plot(figsize=(18,5))
df_train['market_value'].plot()
plt.title('Random Walk vs S&P 500')
plt.show()

# %%
import statsmodels.tsa.stattools as sts

# %%
sts.adfuller(df_train['market_value'])
# Out:
# (-1.7369847452352434,
#  0.4121645696770623,
#  18,
#  5002,
#  {'1%': -3.431658008603046,
#   '5%': -2.862117998412982,
#   '10%': -2.567077669247375},
#  39904.880607487445)

# %%
sts.adfuller(df_train['wn'])
# Out:
# (-71.3355677848104,
#  0.0,
#  0,
#  5020,
#  {'1%': -3.431653316130827,
#   '5%': -2.8621159253018247,
#   '10%': -2.5670765656497516},
#  70747.88527077771)

# %%
sts.adfuller(df_train['rw'])
# Out:
# (-1.3286073927689717,
#  0.6159849181617385,
#  24,
#  4996,
#  {'1%': -3.4316595802782865,
#   '5%': -2.8621186927706463,
#   '10%': -2.567078038881065},
#  46299.333497595144)

# %% [markdown]
# # Naive Decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
s_dec_additive = seasonal_decompose(df['market_value'], model='additive')

# %%
s_dec_additive.plot()

# %%
s_dec_multiplicative = seasonal_decompose(df['market_value'], model='multiplicative')
s_dec_multiplicative.plot()
